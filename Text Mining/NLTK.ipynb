# %% [markdown]
# #Deep Learning con Python
# `Autor: Erwing FC
# ~erwingforerocastro@gmail.com`

# %%
import nltk
#nltk.download('nombreaqui') #para descargar un paquete en especifico
from nltk.book import *
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ####Counting vocabulary of words

# %%
text7
# Out:
# <Text: Wall Street Journal>

# %%
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
sent7

# %%
len(sent7)
# Out:
# 18

# %%
len(text7) #toda las palabras
# Out:
# 100676

# %%
len(set(text7)) #palabras unicas
# Out:
# 12408

# %%
list(set(text7))[:10] #las 10 primeras palabras unicas
# Out:
# ['caustic',
#  'constantly',
#  'commissions',
#  'pit',
#  'unsecured',
#  'recession',
#  'Owner',
#  'above',
#  'write',
#  'Courts']

# %% [markdown]
# ###Frequency of words

# %%
dist = FreqDist(text7) #frecuencia del texto palabra:cantidadApariciones
len(dist)
# Out:
# nltk.probability.FreqDist

# %%
vocab1 = dist.keys() #obtenemos las palabras 
list(vocab1)[:10]
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', 'will', 'join', 'the', 'board']

# %%
dist['four'] #cuantas veces aparece la palabra 'four'
# Out:
# 20

# %%
freqwords = [w for w in vocab1 if len(w) > 5 and dist[w] > 100] #las palabras que tienen una longitud mayor a 5 y aparece mas de 100 veces
freqwords
# Out:
# ['billion',
#  'company',
#  'president',
#  'because',
#  'market',
#  'million',
#  'shares',
#  'trading',
#  'program']

# %% [markdown]
# ###Normalization and stemming

# %%
input1 = "List listed lists listing listings"
words1 = input1.lower().split(' ')
words1
# Out:
# ['list', 'listed', 'lists', 'listing', 'listings']

# %%
#encontramos el stemming o raiz de las palabras
porter = nltk.PorterStemmer()
[porter.stem(t) for t in words1]
# Out:
# ['list', 'list', 'list', 'list', 'list']

# %% [markdown]
# ###Lemmatization

# %%
#palabras que resultan realmente significativas
#nltk.download('udhr')
udhr = nltk.corpus.udhr.words('English-Latin1')
udhr[:20]
# Out:
# [nltk_data] Downloading package udhr to /root/nltk_data...
# [nltk_data]   Unzipping corpora/udhr.zip.
# ['Universal',
#  'Declaration',
#  'of',
#  'Human',
#  'Rights',
#  'Preamble',
#  'Whereas',
#  'recognition',
#  'of',
#  'the',
#  'inherent',
#  'dignity',
#  'and',
#  'of',
#  'the',
#  'equal',
#  'and',
#  'inalienable',
#  'rights',
#  'of']

# %%
[porter.stem(t) for t in udhr[:20]] #no es tan util algunas palabras no serian validas
# Out:
# ['univers',
#  'declar',
#  'of',
#  'human',
#  'right',
#  'preambl',
#  'wherea',
#  'recognit',
#  'of',
#  'the',
#  'inher',
#  'digniti',
#  'and',
#  'of',
#  'the',
#  'equal',
#  'and',
#  'inalien',
#  'right',
#  'of']

# %%
#nltk.download('wordnet')
WNlemma = nltk.WordNetLemmatizer()
[WNlemma.lemmatize(t) for t in udhr[:20]]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# ['Universal',
#  'Declaration',
#  'of',
#  'Human',
#  'Rights',
#  'Preamble',
#  'Whereas',
#  'recognition',
#  'of',
#  'the',
#  'inherent',
#  'dignity',
#  'and',
#  'of',
#  'the',
#  'equal',
#  'and',
#  'inalienable',
#  'right',
#  'of']

# %% [markdown]
# ###Tokenization

# %%
text11 = " Children shouldn't drink a sugary drink before bed. "
text11.lstrip(' ')
# Out:
# "Children shouldn't drink a sugary drink before bed. "

# %%
#nltk.download('punkt')
nltk.word_tokenize(text11)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Children',
#  'should',
#  "n't",
#  'drink',
#  'a',
#  'sugary',
#  'drink',
#  'before',
#  'bed',
#  '.']

# %%
#separamos en sentencias
text12 = "This is the first sentence. A gallon of milk in the U.S. costs $2.99. Is this the third sentence? Yes, it is!"
sentences = nltk.sent_tokenize(text12)
len(sentences)
# Out:
# 4

# %%
sentences
# Out:
# ['This is the first sentence.',
#  'A gallon of milk in the U.S. costs $2.99.',
#  'Is this the third sentence?',
#  'Yes, it is!']

# %% [markdown]
# ##Advanced NLP Tasks with NLTK

# %% [markdown]
# ###POS tagging

# %%
#nltk.download('tagsets')
nltk.help.upenn_tagset('MD')
# Out:
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would

# %%
#nltk.download('averaged_perceptron_tagger')
text14 = nltk.word_tokenize("Visiting aunts can be a nuisance")
nltk.pos_tag(text14)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('Visiting', 'VBG'),
#  ('aunts', 'NNS'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('nuisance', 'NN')]

# %%
text13 = nltk.word_tokenize(text11)
nltk.pos_tag(text13)
#NNP sustantivo plural
#MD modelo
#RB verbo final
#VB verbo
#DT determinante
#JJ adjetivo
#etc...
# Out:
# [('Children', 'NNP'),
#  ('should', 'MD'),
#  ("n't", 'RB'),
#  ('drink', 'VB'),
#  ('a', 'DT'),
#  ('sugary', 'JJ'),
#  ('drink', 'NN'),
#  ('before', 'IN'),
#  ('bed', 'NN'),
#  ('.', '.')]

# %%
text15 = nltk.word_tokenize("Alice loves Bob") #tokeniza la frase
#gramatica libre de contexto
grammar = nltk.CFG.fromstring("""
S -> NP VP
VP -> V NP
NP -> 'Alice' | 'Bob'
V -> 'loves'
""")

parser = nltk.ChartParser(grammar)
trees = parser.parse_all(text15)
for tree in trees:
    print(tree)
# Out:
# (S (NP Alice) (VP (V loves) (NP Bob)))

# %%
text16 = nltk.word_tokenize("I saw the man with a telescope")
grammar1 = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'a' | 'the'
N -> 'man' | 'telescope'
V -> 'saw'
P -> 'with'
""")
parser = nltk.ChartParser(grammar1)
trees = parser.parse_all(text16)
for tree in trees:
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V saw) (NP (Det the) (N man)))
#     (PP (P with) (NP (Det a) (N telescope)))))
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))

# %%
#para hacerlo de una forma mas simple, existe treebank
from nltk.corpus import treebank
text17 = treebank.parsed_sents('wsj_0001.mrg')[0] #walt street journal
print(text17)
# Out:
# (S
#   (NP-SBJ
#     (NP (NNP Pierre) (NNP Vinken))
#     (, ,)
#     (ADJP (NP (CD 61) (NNS years)) (JJ old))
#     (, ,))
#   (VP
#     (MD will)
#     (VP
#       (VB join)
#       (NP (DT the) (NN board))
#       (PP-CLR (IN as) (NP (DT a) (JJ nonexecutive) (NN director)))
#       (NP-TMP (NNP Nov.) (CD 29))))
#   (. .))

# %% [markdown]
# ###POS tagging and parsing ambiguity

# %%
text18 = nltk.word_tokenize("The old man the boat")
nltk.pos_tag(text18)
# Out:
# [('The', 'DT'), ('old', 'JJ'), ('man', 'NN'), ('the', 'DT'), ('boat', 'NN')]

# %%
text19 = nltk.word_tokenize("Colorless green ideas sleep furiously")
nltk.pos_tag(text19)
# Out:
# [('Colorless', 'NNP'),
#  ('green', 'JJ'),
#  ('ideas', 'NNS'),
#  ('sleep', 'VBP'),
#  ('furiously', 'RB')]
