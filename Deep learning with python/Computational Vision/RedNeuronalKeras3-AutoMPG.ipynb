# %% [markdown]
# #Deep Learning con Python
# `Autor: Erwing FC
# ~erwingforerocastro@gmail.com`

# %%
#librerias
# %tensorflow_version 2.x 
import tensorflow as tf 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense

# %%
#obtener los datos
dataset_path = tf.keras.utils.get_file("auto-mpg.data", 
                                       "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data") 

column_names = ['MPG','Cylinders','Displacement', 'Horsepower','Weight', 'Acceleration', 'Model Year', 'Origin']

raw_dataset=pd.read_csv(dataset_path,names=column_names,na_values="?", #leemos los datos y le damos las columnas
                        comment="\t",sep=" ",skipinitialspace=True)
dataset=raw_dataset.copy() #copiamos
dataset.tail() #ultimos 5 datos
# Out:
# Downloading data from https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# 32768/30286 [================================] - 0s 1us/step
#       MPG  Cylinders  Displacement  ...  Acceleration  Model Year  Origin
# 393  27.0          4         140.0  ...          15.6          82       1
# 394  44.0          4          97.0  ...          24.6          82       2
# 395  32.0          4         135.0  ...          11.6          82       1
# 396  28.0          4         120.0  ...          18.6          82       1
# 397  31.0          4         119.0  ...          19.4          82       1
#
# [5 rows x 8 columns]

# %%
print(dataset.isna().sum()) #si faltan valores, faltan 6 valores en HorsePower
dataset = dataset.dropna() #borramos esas filas (esto no se debe hacer en ejemplos reales)
print(dataset.isna().sum())
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
#Origin es categorico, por lo que se realizara la estrategia one-shot
origin=dataset.pop('Origin')
dataset['Usa']=(origin==1)*1.0
dataset['Europe']=(origin==2)*1.0
dataset['Japan']=(origin==3)*1.0
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  ...  Model Year  Usa  Europe  Japan
# 393  27.0          4         140.0        86.0  ...          82  1.0     0.0    0.0
# 394  44.0          4          97.0        52.0  ...          82  0.0     1.0    0.0
# 395  32.0          4         135.0        84.0  ...          82  1.0     0.0    0.0
# 396  28.0          4         120.0        79.0  ...          82  1.0     0.0    0.0
# 397  31.0          4         119.0        82.0  ...          82  1.0     0.0    0.0
#
# [5 rows x 10 columns]

# %%
#Separamos los datos 
train_dataset=dataset.sample(frac=0.8,random_state=0) #80% de los datos
test_dataset=dataset.drop(train_dataset.index) #20% de los datos
#etiquetas
train_labels=train_dataset.pop('MPG')
test_labels=test_dataset.pop('MPG')

print(train_dataset.shape[0])
print(test_dataset.shape[0])
print(train_dataset.shape)
print(test_dataset.shape)
# Out:
# 314
# 78
# (314, 9)
# (78, 9)

# %%
#veamos como son los datos
train_stats=train_dataset.describe() #vemos las medianas y desviaciones
train_stats=train_stats.transpose() #transponemos la matriz
train_stats
# Out:
#               count         mean         std  ...     50%      75%     max
# Cylinders     314.0     5.477707    1.699788  ...     4.0     8.00     8.0
# Displacement  314.0   195.318471  104.331589  ...   151.0   265.75   455.0
# Horsepower    314.0   104.869427   38.096214  ...    94.5   128.00   225.0
# Weight        314.0  2990.251592  843.898596  ...  2822.5  3608.00  5140.0
# Acceleration  314.0    15.559236    2.789230  ...    15.5    17.20    24.8
# Model Year    314.0    75.898089    3.675642  ...    76.0    79.00    82.0
# Usa           314.0     0.624204    0.485101  ...     1.0     1.00     1.0
# Europe        314.0     0.178344    0.383413  ...     0.0     0.00     1.0
# Japan         314.0     0.197452    0.398712  ...     0.0     0.00     1.0
#
# [9 rows x 8 columns]

# %%
#funcion de normalizacion
def norm(x):
  return (x-train_stats['mean'])/train_stats['std']
normed_train_data=norm(train_dataset)
normed_test_data=norm(test_dataset)

#verficamos la normalizacion
normed_train_stats = normed_train_data.describe().transpose() 
normed_train_stats
# Out:
#               count          mean  std  ...       50%       75%       max
# Cylinders     314.0  2.093159e-16  1.0  ... -0.869348  1.483887  1.483887
# Displacement  314.0  1.018294e-16  1.0  ... -0.424785  0.675074  2.489002
# Horsepower    314.0 -1.909301e-17  1.0  ... -0.272190  0.607162  3.153347
# Weight        314.0 -9.723291e-17  1.0  ... -0.198782  0.732017  2.547401
# Acceleration  314.0  2.688832e-15  1.0  ... -0.021237  0.588250  3.313017
# Model Year    314.0  9.561531e-16  1.0  ...  0.027726  0.843910  1.660094
# Usa           314.0  6.081476e-17  1.0  ...  0.774676  0.774676  0.774676
# Europe        314.0  8.485781e-18  1.0  ... -0.465148 -0.465148  2.143005
# Japan         314.0  3.164489e-17  1.0  ... -0.495225 -0.495225  2.012852
#
# [9 rows x 8 columns]

# %%
#modelo de la red
def build_model():
  model=Sequential()
  model.add(Dense(64,activation='relu',
                  input_shape=[len(train_dataset.keys())]))
  model.add(Dense(64,activation='relu'))
  model.add(Dense(1))
  return model
  
model=build_model();
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                640
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
#funcion de perdida
#MSE mean square error o MAE mean absolute error
optimizer=tf.keras.optimizers.RMSprop(0.001)
model.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mae','mse'])
#para evitar el sobreajuste visto abajo añadimos un callback EarlyStopping
early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10)

# %%
#entrenamiento
epochs=1000  #1000 sobreajuste obvio
history=model.fit(normed_train_data,train_labels,
                  epochs=epochs,validation_split=0.2, #validation 20% de los datos
                  verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 549.7226 - mae: 22.1602 - mse: 549.7226 - val_loss: 535.2636 - val_mae: 21.8067 - val_mse: 535.2636
# Epoch 2/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 490.3993 - mae: 20.8375 - mse: 490.3993 - val_loss: 470.9962 - val_mae: 20.3260 - val_mse: 470.9962
# Epoch 3/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 428.7537 - mae: 19.3606 - mse: 428.7537 - val_loss: 400.3554 - val_mae: 18.5754 - val_mse: 400.3554
# Epoch 4/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 362.7785 - mae: 17.6491 - mse: 362.7785 - val_loss: 328.2567 - val_mae: 16.5963 - val_mse: 328.2567
# Epoch 5/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 296.2765 - mae: 15.7322 - mse: 296.2765 - val_loss: 256.7814 - val_mae: 14.4390 - val_mse: 256.7814
# Epoch 6/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 230.3720 - mae: 13.6769 - mse: 230.3720 - val_loss: 189.2626 - val_mae: 12.2138 - val_mse: 189.2626
# Epoch 7/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 170.5463 - mae: 11.5632 - mse: 170.5463 - val_loss: 132.6357 - val_mae: 10.1361 - val_mse: 132.6357
# Epoch 8/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 120.9418 - mae: 9.5479 - mse: 120.9418 - val_loss: 88.5554 - val_mae: 8.1715 - val_mse: 88.5554
# Epoch 9/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 83.4395 - mae: 7.6272 - mse: 83.4395 - val_loss: 59.6800 - val_mae: 6.7071 - val_mse: 59.6800
# Epoch 10/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 58.7191 - mae: 6.1632 - mse: 58.7191 - val_loss: 43.7201 - val_mae: 5.5692 - val_mse: 43.7201
# Epoch 11/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 43.5760 - mae: 5.2381 - mse: 43.5760 - val_loss: 35.1791 - val_mae: 4.9618 - val_mse: 35.1791
# Epoch 12/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 34.3835 - mae: 4.6275 - mse: 34.3835 - val_loss: 30.3690 - val_mae: 4.6066 - val_mse: 30.3690
# Epoch 13/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 28.1716 - mae: 4.1717 - mse: 28.1716 - val_loss: 26.4653 - val_mae: 4.2579 - val_mse: 26.4653
# Epoch 14/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 23.5358 - mae: 3.8184 - mse: 23.5358 - val_loss: 23.6786 - val_mae: 3.9607 - val_mse: 23.6786
# Epoch 15/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 20.2331 - mae: 3.5591 - mse: 20.2331 - val_loss: 21.0065 - val_mae: 3.8026 - val_mse: 21.0065
# Epoch 16/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 17.8558 - mae: 3.3075 - mse: 17.8558 - val_loss: 19.6870 - val_mae: 3.5967 - val_mse: 19.6870
# Epoch 17/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 16.0734 - mae: 3.1472 - mse: 16.0734 - val_loss: 17.1836 - val_mae: 3.4101 - val_mse: 17.1836
# Epoch 18/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 14.8912 - mae: 2.9797 - mse: 14.8912 - val_loss: 16.0847 - val_mae: 3.2741 - val_mse: 16.0847
# Epoch 19/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 13.4966 - mae: 2.8083 - mse: 13.4966 - val_loss: 14.6873 - val_mae: 3.1494 - val_mse: 14.6873
# Epoch 20/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 12.7437 - mae: 2.7007 - mse: 12.7437 - val_loss: 13.6999 - val_mae: 2.9887 - val_mse: 13.6999
# Epoch 21/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 11.8019 - mae: 2.5868 - mse: 11.8019 - val_loss: 12.6157 - val_mae: 2.8278 - val_mse: 12.6157
# Epoch 22/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 11.2847 - mae: 2.4893 - mse: 11.2847 - val_loss: 11.8723 - val_mae: 2.7615 - val_mse: 11.8723
# Epoch 23/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 10.9756 - mae: 2.4247 - mse: 10.9756 - val_loss: 11.3451 - val_mae: 2.7140 - val_mse: 11.3451
# Epoch 24/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 10.1865 - mae: 2.3358 - mse: 10.1865 - val_loss: 10.9205 - val_mae: 2.6111 - val_mse: 10.9205
# Epoch 25/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 9.9738 - mae: 2.2538 - mse: 9.9738 - val_loss: 10.7867 - val_mae: 2.5597 - val_mse: 10.7867
# Epoch 26/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 9.2661 - mae: 2.1921 - mse: 9.2661 - val_loss: 10.4219 - val_mae: 2.6074 - val_mse: 10.4219
# Epoch 27/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 9.2134 - mae: 2.1755 - mse: 9.2134 - val_loss: 10.1835 - val_mae: 2.4389 - val_mse: 10.1835
# Epoch 28/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 8.9444 - mae: 2.1439 - mse: 8.9444 - val_loss: 9.7512 - val_mae: 2.4722 - val_mse: 9.7512
# Epoch 29/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 8.8500 - mae: 2.0980 - mse: 8.8500 - val_loss: 9.4307 - val_mae: 2.4413 - val_mse: 9.4307
# Epoch 30/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 8.5958 - mae: 2.0754 - mse: 8.5958 - val_loss: 9.4366 - val_mae: 2.3870 - val_mse: 9.4366
# Epoch 31/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 8.3816 - mae: 2.0707 - mse: 8.3816 - val_loss: 9.1229 - val_mae: 2.3803 - val_mse: 9.1229
# Epoch 32/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 8.3072 - mae: 2.0420 - mse: 8.3072 - val_loss: 9.1387 - val_mae: 2.3383 - val_mse: 9.1387
# Epoch 33/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.8879 - mae: 2.0154 - mse: 7.8879 - val_loss: 9.2480 - val_mae: 2.4693 - val_mse: 9.2480
# Epoch 34/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 8.1554 - mae: 2.0150 - mse: 8.1554 - val_loss: 8.8558 - val_mae: 2.3112 - val_mse: 8.8558
# Epoch 35/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 7.9534 - mae: 2.0262 - mse: 7.9534 - val_loss: 8.7423 - val_mae: 2.3099 - val_mse: 8.7423
# Epoch 36/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 7.7942 - mae: 1.9882 - mse: 7.7942 - val_loss: 8.7546 - val_mae: 2.2818 - val_mse: 8.7546
# Epoch 37/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.6041 - mae: 1.9909 - mse: 7.6041 - val_loss: 8.7632 - val_mae: 2.2998 - val_mse: 8.7632
# Epoch 38/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.7586 - mae: 2.0051 - mse: 7.7586 - val_loss: 8.8066 - val_mae: 2.2418 - val_mse: 8.8066
# Epoch 39/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 7.5308 - mae: 1.9613 - mse: 7.5308 - val_loss: 8.6397 - val_mae: 2.2518 - val_mse: 8.6397
# Epoch 40/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4979 - mae: 1.9502 - mse: 7.4979 - val_loss: 9.0271 - val_mae: 2.3631 - val_mse: 9.0271
# Epoch 41/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.3833 - mae: 1.9559 - mse: 7.3833 - val_loss: 8.6184 - val_mae: 2.2277 - val_mse: 8.6184
# Epoch 42/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 7.3195 - mae: 1.9441 - mse: 7.3195 - val_loss: 8.4828 - val_mae: 2.2536 - val_mse: 8.4828
# Epoch 43/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.5289 - mae: 1.9614 - mse: 7.5289 - val_loss: 8.6051 - val_mae: 2.3130 - val_mse: 8.6051
# Epoch 44/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.2658 - mae: 1.9170 - mse: 7.2658 - val_loss: 8.7385 - val_mae: 2.1915 - val_mse: 8.7385
# Epoch 45/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.3032 - mae: 1.9167 - mse: 7.3032 - val_loss: 8.5939 - val_mae: 2.2365 - val_mse: 8.5939
# Epoch 46/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.1102 - mae: 1.9062 - mse: 7.1102 - val_loss: 8.5851 - val_mae: 2.2454 - val_mse: 8.5851
# Epoch 47/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.0595 - mae: 1.9036 - mse: 7.0595 - val_loss: 8.4358 - val_mae: 2.1951 - val_mse: 8.4358
# Epoch 48/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.9323 - mae: 1.8945 - mse: 6.9323 - val_loss: 9.3347 - val_mae: 2.1827 - val_mse: 9.3347
# Epoch 49/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 7.0487 - mae: 1.9189 - mse: 7.0487 - val_loss: 8.4084 - val_mae: 2.2523 - val_mse: 8.4084
# Epoch 50/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 7.0472 - mae: 1.8877 - mse: 7.0472 - val_loss: 8.4422 - val_mae: 2.2570 - val_mse: 8.4422
# Epoch 51/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.7623 - mae: 1.8565 - mse: 6.7623 - val_loss: 8.9595 - val_mae: 2.2077 - val_mse: 8.9595
# Epoch 52/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.8687 - mae: 1.8729 - mse: 6.8687 - val_loss: 8.6211 - val_mae: 2.3414 - val_mse: 8.6211
# Epoch 53/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.6379 - mae: 1.8403 - mse: 6.6379 - val_loss: 8.9622 - val_mae: 2.1778 - val_mse: 8.9622
# Epoch 54/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 6.9351 - mae: 1.9077 - mse: 6.9351 - val_loss: 8.4040 - val_mae: 2.1674 - val_mse: 8.4040
# Epoch 55/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.6475 - mae: 1.8311 - mse: 6.6475 - val_loss: 8.2769 - val_mae: 2.2056 - val_mse: 8.2769
# Epoch 56/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.5803 - mae: 1.8487 - mse: 6.5803 - val_loss: 8.9487 - val_mae: 2.3881 - val_mse: 8.9487
# Epoch 57/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.9452 - mae: 1.8803 - mse: 6.9452 - val_loss: 8.3999 - val_mae: 2.1405 - val_mse: 8.3999
# Epoch 58/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 6.7890 - mae: 1.8618 - mse: 6.7890 - val_loss: 8.3061 - val_mae: 2.2854 - val_mse: 8.3061
# Epoch 59/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.6473 - mae: 1.8436 - mse: 6.6473 - val_loss: 8.2278 - val_mae: 2.2505 - val_mse: 8.2278
# Epoch 60/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.5691 - mae: 1.8491 - mse: 6.5691 - val_loss: 8.2847 - val_mae: 2.2940 - val_mse: 8.2847
# Epoch 61/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.7521 - mae: 1.8484 - mse: 6.7521 - val_loss: 8.0379 - val_mae: 2.1640 - val_mse: 8.0379
# Epoch 62/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.5493 - mae: 1.8149 - mse: 6.5493 - val_loss: 8.4201 - val_mae: 2.2608 - val_mse: 8.4201
# Epoch 63/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.5414 - mae: 1.8099 - mse: 6.5414 - val_loss: 8.1749 - val_mae: 2.1120 - val_mse: 8.1749
# Epoch 64/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.5653 - mae: 1.8465 - mse: 6.5653 - val_loss: 8.0213 - val_mae: 2.1614 - val_mse: 8.0213
# Epoch 65/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.5155 - mae: 1.8073 - mse: 6.5155 - val_loss: 7.9701 - val_mae: 2.1260 - val_mse: 7.9701
# Epoch 66/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.4937 - mae: 1.8396 - mse: 6.4937 - val_loss: 8.0780 - val_mae: 2.2111 - val_mse: 8.0780
# Epoch 67/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 6.4361 - mae: 1.7951 - mse: 6.4361 - val_loss: 7.9830 - val_mae: 2.1766 - val_mse: 7.9830
# Epoch 68/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.7801 - mae: 1.8096 - mse: 6.7801 - val_loss: 8.4601 - val_mae: 2.1216 - val_mse: 8.4601
# Epoch 69/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.5939 - mae: 1.8053 - mse: 6.5939 - val_loss: 7.8913 - val_mae: 2.1251 - val_mse: 7.8913
# Epoch 70/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.3755 - mae: 1.8024 - mse: 6.3755 - val_loss: 8.0248 - val_mae: 2.1466 - val_mse: 8.0248
# Epoch 71/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.4903 - mae: 1.8137 - mse: 6.4903 - val_loss: 7.9345 - val_mae: 2.1648 - val_mse: 7.9345
# Epoch 72/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.7345 - mae: 1.8061 - mse: 6.7345 - val_loss: 7.8907 - val_mae: 2.1915 - val_mse: 7.8907
# Epoch 73/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.2690 - mae: 1.7712 - mse: 6.2690 - val_loss: 8.1684 - val_mae: 2.2433 - val_mse: 8.1684
# Epoch 74/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.3853 - mae: 1.7750 - mse: 6.3853 - val_loss: 7.8700 - val_mae: 2.1826 - val_mse: 7.8700
# Epoch 75/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.2818 - mae: 1.8010 - mse: 6.2818 - val_loss: 8.3225 - val_mae: 2.3095 - val_mse: 8.3225
# Epoch 76/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.3640 - mae: 1.7908 - mse: 6.3640 - val_loss: 7.9850 - val_mae: 2.2275 - val_mse: 7.9850
# Epoch 77/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.2536 - mae: 1.7875 - mse: 6.2536 - val_loss: 8.3290 - val_mae: 2.2869 - val_mse: 8.3290
# Epoch 78/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 6.4409 - mae: 1.7888 - mse: 6.4409 - val_loss: 7.7864 - val_mae: 2.1641 - val_mse: 7.7864
# Epoch 79/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.3323 - mae: 1.7835 - mse: 6.3323 - val_loss: 7.8156 - val_mae: 2.1497 - val_mse: 7.8156
# Epoch 80/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 6.1009 - mae: 1.7598 - mse: 6.1009 - val_loss: 8.1540 - val_mae: 2.0736 - val_mse: 8.1540
# Epoch 81/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 6.3423 - mae: 1.7677 - mse: 6.3423 - val_loss: 7.8838 - val_mae: 2.1306 - val_mse: 7.8838
# Epoch 82/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.2178 - mae: 1.7447 - mse: 6.2178 - val_loss: 7.7849 - val_mae: 2.1359 - val_mse: 7.7849
# Epoch 83/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.3676 - mae: 1.7920 - mse: 6.3676 - val_loss: 7.9013 - val_mae: 2.2395 - val_mse: 7.9013
# Epoch 84/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.2741 - mae: 1.7835 - mse: 6.2741 - val_loss: 7.8666 - val_mae: 2.1809 - val_mse: 7.8666
# Epoch 85/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.1911 - mae: 1.7877 - mse: 6.1911 - val_loss: 7.9580 - val_mae: 2.1888 - val_mse: 7.9580
# Epoch 86/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.0420 - mae: 1.7241 - mse: 6.0420 - val_loss: 8.1656 - val_mae: 2.0786 - val_mse: 8.1656
# Epoch 87/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.4278 - mae: 1.7918 - mse: 6.4278 - val_loss: 7.8343 - val_mae: 2.1870 - val_mse: 7.8343
# Epoch 88/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.0914 - mae: 1.7159 - mse: 6.0914 - val_loss: 7.8743 - val_mae: 2.1100 - val_mse: 7.8743
# Epoch 89/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.1454 - mae: 1.7424 - mse: 6.1454 - val_loss: 8.0177 - val_mae: 2.1065 - val_mse: 8.0177
# Epoch 90/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 6.2717 - mae: 1.7719 - mse: 6.2717 - val_loss: 7.7895 - val_mae: 2.1162 - val_mse: 7.7895
# Epoch 91/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.3156 - mae: 1.7781 - mse: 6.3156 - val_loss: 8.0004 - val_mae: 2.2298 - val_mse: 8.0004
# Epoch 92/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 6.1744 - mae: 1.7583 - mse: 6.1744 - val_loss: 8.0239 - val_mae: 2.1972 - val_mse: 8.0239

# %%
#gracias a history podemos ver como el modelo a evolucionado
hist=pd.DataFrame(history.history)
hist['epoch']=history.epoch
hist.tail()

#graficamente 
def plot_history(history,param='mse'):
  hist=pd.DataFrame(history.history)
  hist['epoch']=history.epoch
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean square error')
  plt.plot(hist['epoch'],hist[f'{param}'],label='Train error')  #error del conjunto de  entrenamiento
  plt.plot(hist['epoch'],hist[f'val_{param}'],label='Val error') #eror del conjunto de validacion
  plt.ylim([0,20])
  plt.legend()
  plt.show()

plot_history(history)
plot_history(history,'mae')

# %%
#evaluacion del modelo de los datos
loss, mse, mae = model.evaluate(normed_test_data, test_labels) 
print("Testing set Mean Abs Error: {:5.2f} MPG".format(mae)) 
print("Testing set Mean Sqr Error: {:5.2f} MPG".format(mse)) 

#arroja un error de 5 millas por galon, un error pequeño, por lo que puede estar generalizando bien
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 5.4327 - mae: 1.7715 - mse: 5.4327
# Testing set Mean Abs Error:  5.43 MPG
# Testing set Mean Sqr Error:  1.77 MPG
