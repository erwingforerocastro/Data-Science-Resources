# %% [markdown]
# #Deep Learning con Python
#
#
#
# ### Autor: Erwing FC
#
# #### ~erwingforerocastro@gmail.com

# %%
from google.colab import files
import time
import numpy as np

def suma(a,b):
  """Retorna una suma"""
  return a+b
#información
suma??

# %%
# %time suma(34,5) #tiempo de ejecucion
# %reset #limpiamos todos los namespace

# %%
#para ejecutar un archivo externo
files.upload()
# %run '/content/archivoexterno.py'

# %%
#obtener el script del archivo externo
# %load '/content/archivoexterno.py'

# %%
#guardar un archivo en txt
a=np.random.randint(0,10,(3,5))
np.savetxt('./numpy/ejemplo.txt',a) 
#guardar un archivo en csv
np.savetxt('./numpy/ejemplo.csv',a,delimiter=';') 
#guardar un archivo en binario
np.save('./numpy/ejemplo.npy',a) 
#guardar un archivo en binario comprimido
np.savez('./numpy/ejemplo.npz',a)

# %%
#cargar el archivo guardado
a=np.loadtxt('./numpy/ejemplo.txt') 
b=np.loadtxt('./numpy/ejemplo.csv',delimiter=';')
c=np.load('./numpy/ejemplo.npy')
d=np.load('./numpy/ejemplo.npz')['arr_0']
print(a)
print()
print(b) 
print()
print(c)
print()
print(d)

# %%
#copiar lo siguiente de forma manual quitando comentarios

# Ciudad,Latitud,Longitud
# #comentario
# CDMX,23.55,45.66
# Bombay,55,66.7
# Bogota,44.5,66
# Rio,33.2,5

# #otro comentario

#guardar lo anterior en un archivo ciudades.txt

np.genfromtxt('./numpy/ciudades.txt',usecols=[1,2],skip_header=1,comments='#',delimiter=',') #latitud y longitud
